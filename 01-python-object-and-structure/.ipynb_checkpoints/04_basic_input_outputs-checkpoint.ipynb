# %%
# %%writefile myfile.txt
# Hello this is a text file
# this is the second line
# this is the third line
# Out:
# Overwriting myfile.txt

# %%
myfile = open('myfile.txt')

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
pwd
# Out:
# 'D:\\#Testing Ground\\Python\\the-complete-python-bootcamp\\01-python-object-and-structure'

# %%
myfile = open('myfile.txt')

# %%
myfile
# Out:
# <_io.TextIOWrapper name='myfile.txt' mode='r' encoding='cp1252'>

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.read()
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
myfile.read()
# Out:
# ''

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readlines()
# Out:
# ['Hello this is a text file\n',
#  'this is the second line\n',
#  'this is the third line\n']

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.readline()
# Out:
# 'Hello this is a text file\n'

# %%
myfile.seek(0)
# Out:
# 0

# %%
myfile.close()

# %%
with open('myfile.txt') as my_new_file:
    contents = my_new_file.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt', mode = 'r') as myfile:
    contents = myfile.read()

# %%
contents
# Out:
# 'Hello this is a text file\nthis is the second line\nthis is the third line\n'

# %%
with open('myfile.txt', mode = 'w') as myfile:
    contents = myfile.read()
# Out:
# ---------------------------------------------------------------------------
# UnsupportedOperation                      Traceback (most recent call last)
# Cell In[29], line 2
#       1 with open('myfile.txt', mode = 'w') as myfile:
# ----> 2     contents = myfile.read()
#
# UnsupportedOperation: not readable

# %%
# %%writefile my_new_file.txt
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# Out:
# Writing my_new_file.txt

# %%
with open('my_new_file.txt', mode = 'r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD

# %%
with open('my_new_file.txt', mode = 'a') as f:
    f.write('FOUR ON FOURTH')

# %%
with open('my_new_file.txt', mode = 'r') as f:
    print(f.read())
# Out:
# ONE ON FIRST
# TWO ON SECOND
# THREE ON THIRD
# FOUR ON FOURTH

# %%
with open('SDgsgfgd.txt', mode = 'w') as f:
    f.write('I created this file')

# %%
10 * 10 + 0.25
# Out:
# 100.25

# %%
2 ** 2
# Out:
# 4

# %%
2^3
# Out:
# 1

# %%
sqrt(2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[40], line 1
# ----> 1 sqrt(2)
#
# NameError: name 'sqrt' is not defined

# %%
4^2
# Out:
# 6

# %%
s ='hello'
# Reverse the string using slicing
s[::-1]
# Out:
# 'olleh'

# %%
s ='hello'
# Print out the 'o'
s[4]
# Method 1:
s[-1]
# Out:
# 'o'

# %%
s[4]
# Out:
# 'o'

# %%
mylist = []

# %%
mylist.append(0)

# %%
mylist
# Out:
# [0]

# %%
mylist.append(0)

# %%
mylist.append(0)

# %%
mylist
# Out:
# [0, 0, 0]

# %%
list('000')
# Out:
# ['0', '0', '0']

# %%
mylist = list('000')
mylist[0] = 0
mylist[1] = 0
mylist[2] = 0

# %%
mylist
# Out:
# [0, 0, 0]

# %%
list3 = [1,2,[3,4,'hello']]
list3[2][2] = 'goodbye'
list3
# Out:
# [1, 2, [3, 4, 'goodbye']]

# %%
list4 = [5,3,4,6,1]

list4.sort()
list4
# Out:
# [1, 3, 4, 5, 6]

# %%
d = {'simple_key':'hello'}
# Grab 'hello'
d['simple_key']
# Out:
# 'hello'

# %%
d = {'k1':{'k2':'hello'}}
# Grab 'hello'
d['k1']['k2']
# Out:
# 'hello'

# %%
d = {'k1':[{'nest_key':['this is deep',['hello']]}]}

d['k1'][0]['nest_key'][1]
# Out:
# ['hello']
