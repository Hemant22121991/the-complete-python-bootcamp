# %%
if True:
    print("Its True!")
# Out:
# Its True!

# %%
if 3>2:
    print("Its True!")
# Out:
# Its True!

# %%
hungry = False
if hungry:
    print("Feed Me!")
else:
    print("I m not hungry")
# Out:
# I m not hungry

# %%
loc = 'Bank'

if loc == 'Auto Shop':
    print("Cars are cool!")
elif loc == 'Bank':
    print('Money is cool!')
elif loc == 'Store':
    print("Welcome to the store!")
else:
    print("I dont know much")
# Out:
# Money is cool!
