# %%
text = 'I am home'

# %%
mylist = text.split(' ')

# %%
temp_list = []
final_list = []
for num,val in enumerate(mylist):
    temp_list.append(num)
temp_list.reverse()

for i in temp_list:
    final_list.append(mylist[i])

' '.join(final_list)
# Out:
# 'home am I'

# %%
def blackjack(a,b,c):
    return sum(list(a,b,c))

# %%
blackjack(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 blackjack(1,2,3)
#
# Cell In[20], line 2, in blackjack(a, b, c)
#       1 def blackjack(a,b,c):
# ----> 2     return sum(list(a,b,c))
#
# TypeError: list expected at most 1 argument, got 3
