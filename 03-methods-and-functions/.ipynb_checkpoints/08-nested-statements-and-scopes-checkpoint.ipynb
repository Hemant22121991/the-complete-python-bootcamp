# %%
x = 25

def printer():
    x = 50
    return x

# %%
print(x)
# Out:
# 25

# %%
print(printer())
# Out:
# 50

# %%
# local namespace

lambda num: num ** 2
# Out:
# <function __main__.<lambda>(num)>

# %%
# enclosing local namespace:

name = 'This is a globla string'

def greet():
    name = 'Dhanashri'

    def hello():
        print('Hello ' + name)

    hello()

# %%
greet()
# Out:
# Hello Dhanashri

# %%
# enclosing local namespace:

name = 'This is a globla string'

def greet():
    # name = 'Dhanashri'

    def hello():
        print('Hello ' + name)

    hello()

# %%
greet()
# Out:
# Hello This is a globla string

# %%
# enclosing local namespace:

#global
name = 'This is a globla string'

def greet():
    # Enclosing
    name = 'Dhanashri'

    def hello():
        #Local
        name = 'I am local' 
        print('Hello ' + name)

    hello()

# %%
greet()
# Out:
# Hello I am local

# %%
x = 50

def func(x):
    print(f'X is {x}')

# %%
func(x)
# Out:
# X is 50

# %%
x = 50

def func(x):
    print(f'X is {x}')

    # Local reassingment
    x = 200
    print(f"I just changed locally changed X to {x}")

# %%
func(x)
# Out:
# X is 50
# I just changed locally changed X to 200

# %%
x= 50
def func():
    global x
    print(f'X is {x}')

    # Local reassingment
    x = 'New Value'
    print(f"I just changed locally changed X to {x}")

# %%
func()
# Out:
# X is 50
# I just changed locally changed X to New Value

# %%
x= 50
def func(x):
    
    print(f'X is {x}')

    # Local reassingment
    x = 'New Value'
    print(f"I just changed locally changed X to {x}")
    return x

# %%
print(x)
# Out:
# 50

# %%
x = func(x)
# Out:
# X is 50
# I just changed locally changed X to New Value

# %%
print(x)
# Out:
# New Value
