# %%
mylist = [1,2,3]

# %%
mylist
# Out:
# [1, 2, 3]

# %%
# method
# .append(), .pop() etc

# %%
help(mylist.insert)
# Out:
# Help on built-in function insert:
#
# insert(index, object, /) method of builtins.list instance
#     Insert object before index.

# %%
def my_first_funct(): # functions must be in snake casing, it is general industry practice
    pass

# %%
def say_hello():
    print("Hello")
    print("how")
    print("are you")

# %%
say_hello()
# Out:
# Hello

# %%
say_hello()
# Out:
# Hello
# how
# are you

# %%
def say_hello(name = 'Mandge'):
    print(f'{name}, Hi There!')

# %%
say_hello('Hemant')
# Out:
# Hemant, Hi There!

# %%
say_hello()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 say_hello()
#
# TypeError: say_hello() missing 1 required positional argument: 'name'

# %%
say_hello()
# Out:
# Mandge, Hi There!

# %%
say_hello("Charlie")
# Out:
# Charlie, Hi There!

# %%
def add_num(num1, num2):
    return num1 + num2

# %%
add_num(10,20)
# Out:
# 30

# %%
result = add_num(20,50)

# %%
result
# Out:
# 70

# %%
def print_result(a,b):
    print(a+b)

# %%
def return_result(a,b):
    return a+b

# %%
print_result(10,20)
# Out:
# 30

# %%
result = print_result(10,20)
# Out:
# 30

# %%
result

# %%
type(result)
# Out:
# NoneType

# %%
result = return_result(30,40)

# %%
result
# Out:
# 70

# %%
def my_func(a,b):
    print(a+b)
    return a+b

# %%
my_func(10,20)
# Out:
# 30
# 30

# %% [raw]
# result = my_func(10,20)

# %%
result
# Out:
# 70

# %%
def sum_numbers(num1, num2):
    return num1 + num2

# %%
sum_numbers(10,20)
# Out:
# 30

# %%
sum_numbers('10','20')
# Out:
# '1020'
