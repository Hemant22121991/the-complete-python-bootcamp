# %%
text = 'I am home'

# %%
mylist = text.split(' ')

# %%
temp_list = []
final_list = []
for num,val in enumerate(mylist):
    temp_list.append(num)
temp_list.reverse()

for i in temp_list:
    final_list.append(mylist[i])

' '.join(final_list)
# Out:
# 'home am I'
